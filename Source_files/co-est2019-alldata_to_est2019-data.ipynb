# %%
import pandas as pd

# %%
df_file = 'co-est2019-alldata.csv'

# %%
df = pd.read_csv(df_file, encoding='latin1')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2019  \
# 0        4779736            4780125          4785437  ...          1.917501
# 1          54571              54597            54773  ...          4.847310
# 2         182265             182265           183112  ...         24.017829
# 3          27457              27455            27327  ...         -5.690302
# 4          22915              22915            22870  ...          1.385134
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  \
# ...

# %%
df = df.rename(columns={'STATE':'id','STNAME':'State','CTYNAME':'City','POPESTIMATE2019':'2019_population'})

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  id  COUNTY    State            City  \
# 0      40       3         6   1       0  Alabama         Alabama
# 1      50       3         6   1       1  Alabama  Autauga County
# 2      50       3         6   1       3  Alabama  Baldwin County
# 3      50       3         6   1       5  Alabama  Barbour County
# 4      50       3         6   1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2019  \
# 0        4779736            4780125          4785437  ...          1.917501
# 1          54571              54597            54773  ...          4.847310
# 2         182265             182265           183112  ...         24.017829
# 3          27457              27455            27327  ...         -5.690302
# 4          22915              22915            22870  ...          1.385134
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  \
# ...

# %%
df = df[['id','State','City','2019_population']]

# %%
df.head()
# Out:
#    id    State            City  2019_population
# 0   1  Alabama         Alabama          4903185
# 1   1  Alabama  Autauga County            55869
# 2   1  Alabama  Baldwin County           223234
# 3   1  Alabama  Barbour County            24686
# 4   1  Alabama     Bibb County            22394

# %%
df.to_csv('est2019-data.csv', encoding='utf-8')
