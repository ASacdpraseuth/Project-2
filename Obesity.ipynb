# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
csv_file = "Project2/csvData.csv"
obesity_data_df = pd.read_csv(csv_file)
obesity_data_df.head()
# Out:
#            State  obesityRate       Pop
# 0       Colorado         23.8   5893634
# 1         Hawaii         25.0   1406430
# 2  Massachusetts         25.2   6912239
# 3     California         26.3  39613493
# 4        Vermont         26.6    623251

# %%
obesity_data_df.describe()
# Out:
#        obesityRate           Pop
# count    50.000000  5.000000e+01
# mean     32.098000  6.612588e+06
# std       3.874326  7.457727e+06
# min      23.800000  5.810750e+05
# 25%      29.275000  1.883091e+06
# 50%      32.100000  4.553858e+06
# 75%      34.800000  7.727732e+06
# max      40.800000  3.961349e+07

# %%
obesity_renamed_df = obesity_data_df.rename(columns={"obesityRate": "Obesity Rate",
                                                    "Pop": "Population"})
obesity_renamed_df
# Out:
#              State  Obesity Rate  Population
# 0         Colorado          23.8     5893634
# 1           Hawaii          25.0     1406430
# 2    Massachusetts          25.2     6912239
# 3       California          26.3    39613493
# 4          Vermont          26.6      623251
# 5          Florida          27.0    21944577
# 6         New York          27.1    19299981
# 7       New Jersey          27.3     8874520
# 8          Montana          28.3     1085004
# 9       Washington          28.3     7796941
# 10          Oregon          29.0     4289439
# 11     Connecticut          29.1     3552821
# 12            Utah          29.2     3310774
# 13           Idaho          29.5     1860123
# 14         Wyoming          29.7      581075
# 15    Rhode Island          30.0     1061509
# 16       Minnesota          30.1     5706398
# 17          Alaska          30.5      724357
# 18          Nevada          30.6     3185786
# 19         Arizona          31.4     7520103
# ...

# %%
csv_file = "Project2/raw_data.csv"
health_data_df = pd.read_csv(csv_file)
health_data_df.head()
# Out:
#         State Health Expen
# 0     Alabama      $7,281
# 1      Alaska     $11,064
# 2     Arizona      $6,452
# 3    Arkansas      $7,408
# 4  California      $7,549

# %%
health_data_df.head()
# Out:
#         State Health Expen
# 0     Alabama      $7,281
# 1      Alaska     $11,064
# 2     Arizona      $6,452
# 3    Arkansas      $7,408
# 4  California      $7,549

# %%
rds_connection_string = "postgres:IamJ6OPS1@localhost:5432/project_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
 engine.table_names()
# Out:
# ['obesity_state', 'health_state']

# %%
health_data_df["Health Expen"] = health_data_df["Health Expen"].replace('[\$,]', '', regex=True).astype(int)

# %%
 health_data_df.to_sql(name='health_state', con=engine, if_exists='append', index=False)

# %%
health_data_df.head()
# Out:
#         State  Health Expen
# 0     Alabama          7281
# 1      Alaska         11064
# 2     Arizona          6452
# 3    Arkansas          7408
# 4  California          7549
